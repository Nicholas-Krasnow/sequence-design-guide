# %%
import pandas as pd
import subprocess
import os
import json
from pprint import pprint

# %%
mkdir pdbs_rank001

# %%
folders = [f for f in os.listdir() if os.path.isdir(f)]



for f in os.listdir():
    if os.path.isdir(f):
        if 'ipynb' not in str(f) and 'pdbs' not in f:
            os.chdir(f)
            print (f)
            
            for t in os.listdir():
                if 'rank_001' in t and '.pdb' in t:
                    print(t)
                    subprocess.run(['mv',t,'../pdbs_rank001'])
        
            os.chdir('..')
# Out:
# 38_b9d0e
# 38_b9d0e_unrelaxed_rank_001_alphafold2_ptm_model_3_seed_000.pdb
# 68_94c8e
# 68_94c8e_unrelaxed_rank_001_alphafold2_ptm_model_2_seed_000.pdb
# 70_1dde6
# 70_1dde6_unrelaxed_rank_001_alphafold2_ptm_model_4_seed_000.pdb
# 53_8ede2
# 53_8ede2_unrelaxed_rank_001_alphafold2_ptm_model_5_seed_000.pdb
# 11_8603d
# 11_8603d_unrelaxed_rank_001_alphafold2_ptm_model_3_seed_000.pdb
# 12_e9422
# 12_e9422_unrelaxed_rank_001_alphafold2_ptm_model_3_seed_000.pdb
# 6_189fe
# 6_189fe_unrelaxed_rank_001_alphafold2_ptm_model_5_seed_000.pdb
# 2_5cbbb
# 2_5cbbb_unrelaxed_rank_001_alphafold2_ptm_model_3_seed_000.pdb
# 65_cbdfa
# 65_cbdfa_unrelaxed_rank_001_alphafold2_ptm_model_5_seed_000.pdb
# 5_86195
# 5_86195_unrelaxed_rank_001_alphafold2_ptm_model_3_seed_000.pdb
# 32_d7cf7
# 32_d7cf7_unrelaxed_rank_001_alphafold2_ptm_model_5_seed_000.pdb
# 67_7f566
# 67_7f566_unrelaxed_rank_001_alphafold2_ptm_model_5_seed_000.pdb
# 23_f81ef
# 23_f81ef_unrelaxed_rank_001_alphafold2_ptm_model_1_seed_000.pdb
# ...
